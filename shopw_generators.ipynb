# %% [markdown]
# Import Packages

# %%
import os
import random
from glob import glob
import concurrent.futures

import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
from skimage.transform import resize
from skimage.util import montage 
from skimage.transform import rotate
import nibabel as nib

# %% [markdown]
# **Load and prepare data**

# %%
batch_size = 100
epochs = 100
shape=60
classes = ["MCI", "AD", "CN"]
num_classes = len(classes) 
n_channels = 1
images_shape = (shape,shape,shape)
project_dir = "/home/pmeslaf/TFM/DATA/FIRST_VISIT_DATA_nougmented/"

# %%
from modelos_pseudo3D.data_generator_ps3D import DataGenerator

training_generator = DataGenerator(data_path=project_dir + '/Train/',
                                   dim=images_shape,
                                   batch_size = batch_size,
                                   n_channels = n_channels,
                                   classes = classes,
                                   test=False,
                                   shuffle=True
                                   )
valid_generator = DataGenerator(data_path=project_dir + '/Validation/',
                                   dim=images_shape,
                                   batch_size = batch_size,
                                   n_channels = n_channels,
                                   classes = classes,
                                   test=False,
                                   shuffle=True)
test_generator = DataGenerator(data_path=project_dir + '/Test/',
                                   dim=images_shape,
                                   batch_size = 126,
                                   n_channels = n_channels,
                                   classes = classes,
                                   test=True,
                                   shuffle=True)
# Out:
# 4550 image(s) found in /home/pmeslaf/TFM/DATA/FIRST_VISIT_DATA_nougmented//Train/
# 580 image(s) found in /home/pmeslaf/TFM/DATA/FIRST_VISIT_DATA_nougmented//Validation/
# 126 image(s) found in /home/pmeslaf/TFM/DATA/FIRST_VISIT_DATA_nougmented//Test/

# %%
X, _ = training_generator[0]

fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()

# %%
X, _ = valid_generator[0]

fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()

# %%
X, _ = test_generator[0]

fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()
