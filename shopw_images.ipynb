# %% [markdown]
# Import Packages

# %%
import os
import random
from glob import glob
import concurrent.futures

import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
from skimage.transform import resize
from skimage.util import montage 
from skimage.transform import rotate
import nibabel as nib

# %% [markdown]
# **Load and prepare data**

# %%
dim = (60,60,60)
project_dir = "/home/pmeslaf/TFM/DATA/FIRST_VISIT_DATA_nougmented/"

# %%
def __load_data(img_path):
    # load nibabel Method
    img = nib.load(img_path).get_fdata()
    # img = ndimage.rotate(img, 90, axes=(0,2), reshape=True)
    img = resize(img, (dim[0], dim[1], dim[2]))

    #NORMALIZATION
    img = (img - np.mean(img)) / np.std(img) #whitening
    img = (img-np.min(img))/np.max(img) #We normalize between 0 an 1

    return img

def __load_data_raw(img_path):
    # load nibabel Method
    img = nib.load(img_path).get_fdata()
    # img = ndimage.rotate(img, 90, axes=(0,2), reshape=True)
    # img = resize(img, (dim[0], dim[1], dim[2]))

    #NORMALIZATION
    # img = (img - np.mean(img)) / np.std(img) #whitening
    # img = (img-np.min(img))/np.max(img) #We normalize between 0 an 1

    return img

# %%
files = [os.path.relpath(file_dir, project_dir) for x in os.walk(project_dir) for file_dir in glob(os.path.join(x[0], '*.nii.gz'))]
batch_size = len(files)
batch_size
# Out:
# 640

# %%
X = np.zeros((100, *dim))
start = 0
for c in range(start,start + 100): 
    file_dir = files[c]
    img_path = os.path.join(project_dir, file_dir);
    img = __load_data(img_path=img_path)
    X[c - start,:,:,:] = img
    print(str(c) + " " + file_dir)
# Out:
# 0 128_S_1242_I134505_masked_basic.nii.gz
# 1 Validation/CN/009_S_0842_I89575_masked_basic.nii.gz
# 2 Validation/CN/014_S_0519_I39647_masked_basic.nii.gz
# 3 Validation/CN/012_S_0637_I59243_masked_basic.nii.gz
# 4 Validation/CN/010_S_0067_I96211_masked_basic.nii.gz
# 5 Validation/CN/014_S_0520_I39660_masked_basic.nii.gz
# 6 Validation/CN/011_S_0023_I32409_masked_basic.nii.gz
# 7 Validation/CN/011_S_0005_I32246_masked_basic.nii.gz
# 8 Validation/CN/011_S_0022_I32389_masked_basic.nii.gz
# 9 Validation/CN/011_S_0016_I32306_masked_basic.nii.gz
# 10 Validation/CN/013_S_1035_I51165_masked_basic.nii.gz
# 11 Validation/CN/009_S_0862_I121228_masked_basic.nii.gz
# 12 Validation/CN/012_S_1009_I64717_masked_basic.nii.gz
# 13 Validation/CN/010_S_0419_I63320_masked_basic.nii.gz
# 14 Validation/CN/010_S_0472_I62630_masked_basic.nii.gz
# 15 Validation/CN/012_S_1133_I59224_masked_basic.nii.gz
# 16 Validation/CN/013_S_0575_I51160_masked_basic.nii.gz
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()

# %%
X = np.zeros((100, *dim))
start = 100
for c in range(start,start + 100): 
    file_dir = files[c]
    img_path = os.path.join(project_dir, file_dir);
    img = __load_data(img_path=img_path)
    X[c - start,:,:,:] = img
    print(str(c) + " " + file_dir)
# Out:
# 100 Train/CN/024_S_1063_I63392_masked_basic.nii.gz
# 101 Train/CN/037_S_0467_I108505_masked_basic.nii.gz
# 102 Train/CN/082_S_1256_I63155_masked_basic.nii.gz
# 103 Train/CN/100_S_0015_I33066_masked_basic.nii.gz
# 104 Train/CN/073_S_0311_I39868_masked_basic.nii.gz
# 105 Train/CN/032_S_0677_I37228_masked_basic.nii.gz
# 106 Train/CN/027_S_0120_I34332_masked_basic.nii.gz
# 107 Train/CN/131_S_0123_I63784_masked_basic.nii.gz
# 108 Train/CN/037_S_0454_I79755_masked_basic.nii.gz
# 109 Train/CN/027_S_0074_I34316_masked_basic.nii.gz
# 110 Train/CN/141_S_0726_I94824_masked_basic.nii.gz
# 111 Train/CN/941_S_1194_I63847_masked_basic.nii.gz
# 112 Train/CN/032_S_1169_I65052_masked_basic.nii.gz
# 113 Train/CN/032_S_0479_I36469_masked_basic.nii.gz
# 114 Train/CN/029_S_0824_I96284_masked_basic.nii.gz
# 115 Train/CN/052_S_1251_I62282_masked_basic.nii.gz
# 116 Train/CN/141_S_0767_I47306_masked_basic.nii.gz
# 117 Train/CN/116_S_0648_I59666_masked_basic.nii.gz
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()

# %%
X = np.zeros((100, *dim))
start = 200
for c in range(start,start + 100): 
    file_dir = files[c]
    img_path = os.path.join(project_dir, file_dir);
    img = __load_data(img_path=img_path)
    X[c - start,:,:,:] = img
    print(str(c) + " " + file_dir)
# Out:
# 200 Train/AD/131_S_0497_I48038_masked_basic.nii.gz
# 201 Train/AD/027_S_0850_I48996_masked_basic.nii.gz
# 202 Train/AD/136_S_0426_I40356_masked_basic.nii.gz
# 203 Train/AD/033_S_0739_I42441_masked_basic.nii.gz
# 204 Train/AD/133_S_1170_I89957_masked_basic.nii.gz
# 205 Train/AD/136_S_0194_I40239_masked_basic.nii.gz
# 206 Train/AD/099_S_0372_I34549_masked_basic.nii.gz
# 207 Train/AD/141_S_0696_I82738_masked_basic.nii.gz
# 208 Train/AD/116_S_0487_I59686_masked_basic.nii.gz
# 209 Train/AD/024_S_1171_I63406_masked_basic.nii.gz
# 210 Train/AD/067_S_0029_I38717_masked_basic.nii.gz
# 211 Train/AD/136_S_0300_I40328_masked_basic.nii.gz
# 212 Train/AD/036_S_0577_I36914_masked_basic.nii.gz
# 213 Train/AD/094_S_1027_I49527_masked_basic.nii.gz
# 214 Train/AD/032_S_0400_I36459_masked_basic.nii.gz
# 215 Train/AD/123_S_0088_I64400_masked_basic.nii.gz
# 216 Train/AD/027_S_1385_I47574_masked_basic.nii.gz
# 217 Train/AD/068_S_0109_I63454_masked_basic.nii.gz
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()

# %%
X = np.zeros((100, *dim))
start = 300
for c in range(start,start + 100): 
    file_dir = files[c]
    img_path = os.path.join(project_dir, file_dir);
    img = __load_data(img_path=img_path)
    X[c - start,:,:,:] = img
    print(str(c) + " " + file_dir)
# Out:
# 300 Train/MCI/114_S_0410_I39824_masked_basic.nii.gz
# 301 Train/MCI/029_S_1073_I65022_masked_basic.nii.gz
# 302 Train/MCI/098_S_0667_I89495_masked_basic.nii.gz
# 303 Train/MCI/033_S_0922_I42493_masked_basic.nii.gz
# 304 Train/MCI/067_S_0077_I68120_masked_basic.nii.gz
# 305 Train/MCI/136_S_0107_I40445_masked_basic.nii.gz
# 306 Train/MCI/053_S_0389_I65676_masked_basic.nii.gz
# 307 Train/MCI/041_S_1412_I72219_masked_basic.nii.gz
# 308 Train/MCI/131_S_1389_I81972_masked_basic.nii.gz
# 309 Train/MCI/114_S_1118_I49768_masked_basic.nii.gz
# 310 Train/MCI/136_S_0195_I40452_masked_basic.nii.gz
# 311 Train/MCI/041_S_0282_I39486_masked_basic.nii.gz
# 312 Train/MCI/027_S_0417_I34226_masked_basic.nii.gz
# 313 Train/MCI/137_S_0668_I43001_masked_basic.nii.gz
# 314 Train/MCI/127_S_1419_I73656_masked_basic.nii.gz
# 315 Train/MCI/027_S_1213_I47223_masked_basic.nii.gz
# 316 Train/MCI/116_S_0752_I59637_masked_basic.nii.gz
# 317 Train/MCI/130_S_0505_I39142_masked_basic.nii.gz
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()

# %%
X = np.zeros((100, *dim))
start = 400
for c in range(start,start + 100): 
    file_dir = files[c]
    img_path = os.path.join(project_dir, file_dir);
    img = __load_data(img_path=img_path)
    X[c - start,:,:,:] = img
    print(str(c) + " " + file_dir)
# Out:
# 400 Train/MCI/131_S_0384_I48002_masked_basic.nii.gz
# 401 Train/MCI/109_S_1343_I66176_masked_basic.nii.gz
# 402 Train/MCI/057_S_0941_I34747_masked_basic.nii.gz
# 403 Train/MCI/127_S_0112_I35799_masked_basic.nii.gz
# 404 Train/MCI/027_S_0307_I34159_masked_basic.nii.gz
# 405 Train/MCI/127_S_0393_I34393_masked_basic.nii.gz
# 406 Train/MCI/068_S_0872_I140335_masked_basic.nii.gz
# 407 Train/MCI/041_S_1010_I65230_masked_basic.nii.gz
# 408 Train/MCI/109_S_1114_I63489_masked_basic.nii.gz
# 409 Train/MCI/062_S_1182_I50566_masked_basic.nii.gz
# 410 Train/MCI/116_S_1315_I59718_masked_basic.nii.gz
# 411 Train/MCI/041_S_0446_I40433_masked_basic.nii.gz
# 412 Train/MCI/123_S_1300_I66305_masked_basic.nii.gz
# 413 Train/MCI/027_S_1045_I47210_masked_basic.nii.gz
# 414 Train/MCI/041_S_1260_I65239_masked_basic.nii.gz
# 415 Train/MCI/032_S_0214_I37224_masked_basic.nii.gz
# 416 Train/MCI/141_S_0915_I48563_masked_basic.nii.gz
# 417 Train/MCI/141_S_1255_I48608_masked_basic.nii.gz
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()

# %%
X = np.zeros((100, *dim))
start = 500
for c in range(start,start + 100): 
    file_dir = files[c]
    img_path = os.path.join(project_dir, file_dir);
    img = __load_data(img_path=img_path)
    X[c - start,:,:,:] = img
    print(str(c) + " " + file_dir)
# Out:
# 500 Train/MCI/141_S_0851_I47870_masked_basic.nii.gz
# 501 Train/MCI/137_S_0722_I43022_masked_basic.nii.gz
# 502 Train/MCI/136_S_0695_I70924_masked_basic.nii.gz
# 503 Train/MCI/137_S_0973_I43060_masked_basic.nii.gz
# 504 Train/MCI/128_S_1407_I69390_masked_basic.nii.gz
# 505 Train/MCI/137_S_0669_I43009_masked_basic.nii.gz
# 506 Train/MCI/029_S_0914_I124879_masked_basic.nii.gz
# 507 Train/MCI/057_S_1217_I62984_masked_basic.nii.gz
# 508 Train/MCI/037_S_0501_I79773_masked_basic.nii.gz
# 509 Train/MCI/041_S_0679_I40046_masked_basic.nii.gz
# 510 Train/MCI/116_S_0834_I59798_masked_basic.nii.gz
# 511 Train/MCI/057_S_1007_I47765_masked_basic.nii.gz
# 512 Train/MCI/053_S_0507_I80199_masked_basic.nii.gz
# 513 Train/MCI/027_S_0461_I34231_masked_basic.nii.gz
# 514 Test/CN/021_S_0984_I33476_masked_basic.nii.gz
# 515 Test/CN/021_S_0647_I33457_masked_basic.nii.gz
# 516 Test/CN/007_S_0068_I35790_masked_basic.nii.gz
# 517 Test/CN/002_S_1280_I60056_masked_basic.nii.gz
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()

# %%
lista= [
    "Validation/CN/009_S_0842_I89575_masked_basic.nii.gz",
    "Train/CN/128_S_1242_I134505_masked_basic.nii.gz"
]

X = np.zeros((len(lista) + 1, *dim))
for c in range(0,len(lista)): 
    file_dir = lista[c]
    img_path = os.path.join(project_dir, file_dir);
    img = __load_data(img_path=img_path)
    X[c,:,:,:] = img
    print(str(c) + " " + file_dir)

img = X[len(lista)-1,:,:,:]
img = ndimage.rotate(img, -90, axes=(1,0), reshape=True)
img = ndimage.rotate(img, 180, axes=(2,1), reshape=True)
X[len(lista),:,:,:] = img

fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(montage(X[:,:,:,30]), cmap ='gray')
plt.show()
# Out:
# 0 Validation/CN/009_S_0842_I89575_masked_basic.nii.gz
# 1 Train/CN/128_S_1242_I134505_masked_basic.nii.gz

# %%
file_dir = "Train/CN/128_S_1242_I134505_masked_basic.nii.gz"
img_path = os.path.join(project_dir, file_dir);
img = __load_data_raw(img_path=img_path)
print(img.shape)

fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(img[:,:,80], cmap ='gray')
plt.show()

img = ndimage.rotate(img, -90, axes=(1,0), reshape=True)
print(img.shape)
img = ndimage.rotate(img, 180, axes=(2,1), reshape=True)

fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(img[:,:,79], cmap ='gray')
plt.show()


# img = nib.Nifti1Image(img, np.eye(4))
# print(img.shape)
# output_path = os.path.join(project_dir, 'Train/CN/128_S_1242_I134505_masked_basic.nii.gz')
# nib.save(img, output_path)
# Out:
# (192, 192, 160)
# (192, 192, 160)
# (192, 192, 160)
